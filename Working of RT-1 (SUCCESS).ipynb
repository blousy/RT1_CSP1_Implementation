# %% [markdown]
# ### Demo for Robotics Transformer 1, with Training, Validation and Visualization Pipeline

# %%
# !git clone https://github.com/ioai-tech/pytorch_rt1_with_trainer_and_tester.git
# Out:
# Cloning into 'pytorch_rt1_with_trainer_and_tester'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 351 (delta 62), reused 58 (delta 58), pack-reused 279 (from 1)
# Receiving objects: 100% (351/351), 44.20 MiB | 12.53 MiB/s, done.
# Resolving deltas: 100% (211/211), done.

# %%
# uncomment if you are running on colab to mount your google drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# When we are running codes in the colab, we need to mount google drives and read codes. Put the path to this repo's code at your google drive into this path

# %%
import sys
sys.path.append("/content/pytorch_rt1_with_trainer_and_tester")

# %% [markdown]
# Installing necessary dependencies

# %%
! pip install -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt
# pybullet building can take 10 minutes(https://github.com/bulletphysics/bullet3/issues/4485), if you don't want to wait too long, change python to previous version(3.7)
# Out:
# Requirement already satisfied: absl-py==2.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: cachetools==5.3.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 2)) (5.3.2)
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: charset-normalizer==3.3.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: cloudpickle==3.0.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: contourpy==1.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools==4.44.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 8)) (4.44.3)
# Requirement already satisfied: func-timeout==4.3.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 9)) (4.3.5)
# Requirement already satisfied: google-auth==2.23.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 10)) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib==1.1.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: grpcio==1.59.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 12)) (1.59.2)
# Requirement already satisfied: gym==0.26.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 13)) (0.26.2)
# Requirement already satisfied: gym-notices==0.0.8 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 14)) (0.0.8)
# Requirement already satisfied: idna==3.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 15)) (3.4)
# Requirement already satisfied: imageio==2.32.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 16)) (2.32.0)
# Requirement already satisfied: kiwisolver==1.4.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 17)) (1.4.5)
# Requirement already satisfied: lazy_loader==0.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 18)) (0.3)
# Requirement already satisfied: Markdown==3.5.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 19)) (3.5.1)
# Requirement already satisfied: MarkupSafe==2.1.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 20)) (2.1.3)
# Requirement already satisfied: matplotlib==3.8.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 21)) (3.8.1)
# Requirement already satisfied: networkx==3.2.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 22)) (3.2.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 23)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 24)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 25)) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 26)) (8.5.0.96)
# Requirement already satisfied: oauthlib==3.2.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 27)) (3.2.2)
# Requirement already satisfied: pandas==2.1.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 28)) (2.1.3)
# Requirement already satisfied: Pillow==10.0.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 29)) (10.0.1)
# Requirement already satisfied: protobuf==4.23.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 30)) (4.23.4)
# Requirement already satisfied: pyasn1==0.5.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 31)) (0.5.0)
# Requirement already satisfied: pyasn1-modules==0.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 32)) (0.3.0)
# Requirement already satisfied: pybullet==3.2.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 33)) (3.2.5)
# Requirement already satisfied: pyparsing==3.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 34)) (3.1.1)
# Requirement already satisfied: pytz==2023.3.post1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 35)) (2023.3.post1)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 36)) (2.31.0)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 37)) (1.3.1)
# Requirement already satisfied: rsa==4.9 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 38)) (4.9)
# Requirement already satisfied: scikit-image==0.22.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 39)) (0.22.0)
# Requirement already satisfied: scikit-video==1.1.11 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 40)) (1.1.11)
# Requirement already satisfied: scipy==1.11.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 41)) (1.11.3)
# Requirement already satisfied: tensorboard==2.15.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 42)) (2.15.1)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 43)) (0.7.2)
# Requirement already satisfied: tifffile==2023.9.26 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 44)) (2023.9.26)
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 45)) (1.13.1)
# Requirement already satisfied: torchvision==0.14.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 46)) (0.14.1)
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 47)) (4.66.1)
# Requirement already satisfied: tzdata==2023.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 48)) (2023.3)
# Requirement already satisfied: urllib3==2.1.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 49)) (2.1.0)
# Requirement already satisfied: Werkzeug==3.0.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 50)) (3.0.1)
# Requirement already satisfied: numpy<2.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from contourpy==1.2.0->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 21)) (24.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.8.1->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 21)) (2.8.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 23)) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 23)) (0.45.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard==2.15.1->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 42)) (1.16.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->-r /content/pytorch_rt1_with_trainer_and_tester/requirements.txt (line 45)) (4.12.2)

# %%
import requests

def download_large_file_from_google_drive(file_id, destination):
    URL = "https://docs.google.com/uc?export=download"
    session = requests.Session()

    response = session.get(URL, params={'id': file_id}, stream=True)
    token = get_confirm_token(response)

    if token:
        params = {'id': file_id, 'confirm': token}
        response = session.get(URL, params=params, stream=True)

    save_response_content(response, destination)

def get_confirm_token(response):
    for key, value in response.cookies.items():
        if key.startswith('download_warning'):
            return value
    return None

def save_response_content(response, destination):
    with open(destination, "wb") as f:
        for chunk in response.iter_content(32768):
            if chunk:  # filter out keep-alive new chunks
                f.write(chunk)

file_id = "1RoTxnipQf2SIXqzvroDOXAleNvvNIIwZ"
destination = "/content/pretrained_rt1.pth"
download_large_file_from_google_drive(file_id, destination)
print("File downloaded!")
# Out:
# File downloaded!

# %%
# class RT1Model(torch.nn.Module):
#     def __init__(self):
#         super().__init__()
#         # Define the layers here

# %%
# model = RT1Model()

# %%
# import torch

# # Path to the model file
# model_path = "/content/pretrained_rt1.pth"

# # Replace `RT1Model` with the actual class of your model
# model = RT1Model()  # Use your actual model class
# model.load_state_dict(torch.load(model_path))  # Load pre-trained weights

# # If using GPU:
# model.to('cuda')  # Move model to GPU if available

# print("Model loaded successfully!")

# %%
# package for downloading pre-trained model parameters and dataset
# !pip install gdown
# !gdown 'https://drive.google.com/uc?export=download&id=1USLqOfqYfqIrigx1hkY37SGyrLJuaPwc'
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1USLqOfqYfqIrigx1hkY37SGyrLJuaPwc
# From (redirected): https://drive.google.com/uc?export=download&id=1USLqOfqYfqIrigx1hkY37SGyrLJuaPwc&confirm=t&uuid=6b385cb2-b3a7-4dbd-8507-4392fd253e73
# To: /content/pretrained_rt1.pth
# 100% 649M/649M [00:04<00:00, 132MB/s]

# %%
# !gdown 'https://drive.google.com/uc?export=download&id=1RoTxnipQf2SIXqzvroDOXAleNvvNIIwZ'

# %%
# import gdown

# # Google Drive file ID
# file_id = "1-3lTbJZ36k40s6umblJLbaznVKQJY1G-"

# # Direct download URL
# url = f"https://drive.google.com/uc?export=download&id={file_id}"

# # Path to save the downloaded file
# output_path = "/content/pretrained_rt1.pth"

# # Download the file
# gdown.download(url, output_path, quiet=False)

# print("File downloaded successfully!")

# %%
import gdown

# Google Drive file ID
file_id = "1-3lTbJZ36k40s6umblJLbaznVKQJY1G-"

# Direct download URL
url = f"https://drive.google.com/uc?export=download&id={file_id}"

# Path to save the downloaded file
# output_path = "/content/pretrained_rt1.pth"

# Download the file
gdown.download(url, quiet=False)

print("File downloaded successfully!")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?export=download&id=1-3lTbJZ36k40s6umblJLbaznVKQJY1G-
# From (redirected): https://drive.google.com/uc?export=download&id=1-3lTbJZ36k40s6umblJLbaznVKQJY1G-&confirm=t&uuid=dfafb658-f5a8-4c3c-aaba-5c3c11faa862
# To: /content/IO_pybullet_open_dataset.zip
# 100%|██████████| 7.94G/7.94G [01:22<00:00, 96.5MB/s]
# File downloaded successfully!

# %%
# !https://drive.google.com/uc?export=download&id=1-3lTbJZ36k40s6umblJLbaznVKQJY1G-&confirm=TOKEN

# %%
# import torch

# # Path to the downloaded file
# model_path = "/content/pretrained_rt1.pth"

# # Replace `RT1Model` with your actual model class
# model = RT1Model()  # Initialize your model
# model.load_state_dict(torch.load(model_path))  # Load the pre-trained weights

# # Move the model to GPU if available
# model.to('cuda' if torch.cuda.is_available() else 'cpu')

# print("Model loaded successfully!")

# %%
# import torch

# # Path to the model file
# model_path = "/content/pretrained_rt1.pth"

# # Load the model (modify `YourModelClass` to match your model class)
# model = YourModelClass()  # Initialize your model architecture
# model.load_state_dict(torch.load(model_path))  # Load pre-trained weights

# # If using GPU:
# model.to('cuda')  # Move model to GPU if available

# print("Model loaded successfully!")

# %%
# !https://drive.google.com/file/d/16OhzH4rYNO10-O-Rx99RkkwsBgp0FXIx/view?usp=sharing

# %%
# !https://drive.google.com/uc?export=download&id=16OhzH4rYNO10-O-Rx99RkkwsBgp0FXIx

# %%
# !unzip /content/pretrained_rt1.pth

# %%
# !unzip /content/pretrained_rt1.pth

# %%
# !unzip /content/IO_pybullet_open_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_130/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_307/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_018/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_170/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_04083.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_04395.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_04187.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_04500.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_04291.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_320/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_223/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_04083.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_04395.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_04187.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_04500.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_04291.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_074/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_404/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_152/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_161/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_358/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_04083.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_04395.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_04187.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_04291.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_041/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_409/rgb/image_02679.png
# ...
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_403/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_071/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04708.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04604.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04083.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04395.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04187.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04500.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_04291.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_073/result_raw.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/result.csv
#    creating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01874.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01770.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01562.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01041.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04708.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04604.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04083.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02179.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00416.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01354.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01145.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04395.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04187.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00004.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01458.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02779.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00729.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00937.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02279.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01249.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00108.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02079.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04500.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00833.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01979.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00312.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04812.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00208.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_01666.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00624.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_00520.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_04291.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_02679.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03479.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03379.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03879.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/rgb/image_03579.png
#   inflating: IO_pybullet_open_dataset/Panda_pick/fronttop/data_328/result_raw.csv

# %%
import sys
sys.path.append('/path/to/util')

# %%
sys.path.append("/content/pytorch_rt1_with_trainer_and_tester")

# %% [markdown]
# Import necessary dependencies

# %%
import copy
import time
import random
from collections import OrderedDict
import func_timeout
from PIL import Image
from func_timeout import func_set_timeout
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import DataLoader

from gym import spaces
from skvideo.io import vwrite
import pybullet as p
import pybullet_data as pdata

from tqdm import tqdm, trange

import util.misc as utils
from IO_dataset_torch import build_dataset
from maruya24_rt1.tokenizers.utils import batched_space_sampler, np_to_tensor
from maruya24_rt1.transformer_network import TransformerNetwork
from maruya24_rt1.transformer_network_test_set_up import state_space_list

# %% [markdown]
# Args for training, set your log directory in "log_dir", and adjust "batch_size" according to your gpu memory, and put downloaded dataset path in "data_path"

# %%
args = {
    "mode": "train",
    "device": "cuda",
    "data_path": "/content/IO_pybullet_open_dataset/Panda_pick",
    "cam_view": ["front", "wrist"],
    "log_dir": "logs",
    "time_sequence_length": 6,
    "lr": 0.0001,
    "batch_size": 2,
    "epochs": 50,
    "resume": False,
    "resume_from_checkpoint": "",
    "predicting_next_ts": True,
    "world_size": 1,
    "dist_url": "env://",
    "val_interval": 1,
    "num_val_threads": 25,
    "num_train_episode": 200,
    "num_val_episode": 10,
    "using_proprioception": False,
    "network_configs": {
        "vocab_size": 256,
        "token_embedding_size_per_image": 512,
        "language_embedding_size": 512,
        "num_layers": 8,
        "layer_size": 128,
        "num_heads": 8,
        "feed_forward_size": 512,
        "dropout_rate": 0.1,
        "crop_size": 236,
        "use_token_learner": True,
    },
    "scheduler_configs": {"T_0": 10, "T_mult": 2, "eta_min": 1e-6, "verbose": True},
}

# %% [markdown]
# Building the training and validation dataset

# %%
train_dataset, val_dataset = build_dataset(
    data_path=args["data_path"],
    time_sequence_length=args["time_sequence_length"],
    predicting_next_ts=args["predicting_next_ts"],
    num_train_episode=args["num_train_episode"],
    num_val_episode=args["num_val_episode"],
    cam_view=args["cam_view"],
    language_embedding_size=args["network_configs"]["language_embedding_size"],
)

# %% [markdown]
# Action space for the network, tokenizer need this to tokenize continuous actions into discrete tokens

# %%
action_space = spaces.Dict(
    OrderedDict(
        [
            ("terminate_episode", spaces.Discrete(4)),
            (
                "world_vector",
                spaces.Box(low=-0.1, high=0.1, shape=(3,), dtype=np.float32),
            ),
            (
                "rotation_delta",
                spaces.Box(
                    low=-np.pi / 5, high=np.pi / 5, shape=(3,), dtype=np.float32
                ),
            ),
            (
                "gripper_closedness_action",
                spaces.Box(low=-1.0, high=1.0, shape=(1,), dtype=np.float32),
            ),
        ]
    )
)

# %% [markdown]
# Initialize the network, noting that the network has number of image encoders equal to that of camera views, and token embedding size increase along with number of camera views

# %%
# Initialize the TransformerNetwork based on specified configurations
network_configs = args["network_configs"]
# Modify network configuration based on specific settings
network_configs["time_sequence_length"] = args["time_sequence_length"]
network_configs["num_encoders"] = len(args["cam_view"])
network_configs["token_embedding_size"] = network_configs[
    "token_embedding_size_per_image"
] * len(args["cam_view"])
del network_configs["token_embedding_size_per_image"]
network_configs["using_proprioception"] = args["using_proprioception"]
network_configs["input_tensor_space"] = state_space_list()[0]
network_configs["output_tensor_space"] = action_space
network = TransformerNetwork(**network_configs)
device = torch.device(args["device"])
network.to(device)
# Out:
# TransformerNetwork(
#   (_image_tokenizers): ModuleDict(
#     (0): RT1ImageTokenizer(
#       (_tokenizer): EfficientNetEncoder(
#         (conv1x1): Conv2d(1536, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (net): EfficientNet(
#           (convNormAct0): Conv2dNormActivation(
#             (0): Conv2d(3, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (blocks): ModuleList(
#             (0): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#                   (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (2): Conv2dNormActivation(
#                   (0): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (1): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#                   (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (2): Conv2dNormActivation(
#                   (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.007692307692307693, mode=row)
#             )
#             (2): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#                   (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.015384615384615385, mode=row)
#             )
#             (3): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.02307692307692308, mode=row)
#             )
#             (4): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.03076923076923077, mode=row)
#             )
#             (5): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.038461538461538464, mode=row)
#             )
#             (6): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#                   (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.04615384615384616, mode=row)
#             )
#             (7): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#                   (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.05384615384615385, mode=row)
#             )
#             (8): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#                   (1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.06153846153846154, mode=row)
#             )
#             (9): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.06923076923076923, mode=row)
#             )
#             (10): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.07692307692307693, mode=row)
#             )
#             (11): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.08461538461538462, mode=row)
#             )
#             (12): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.09230769230769233, mode=row)
#             )
#             (13): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#                   (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(576, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.1, mode=row)
#             )
#             (14): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.1076923076923077, mode=row)
#             )
#             (15): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.11538461538461539, mode=row)
#             )
#             (16): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.12307692307692308, mode=row)
#             )
#             (17): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=816, bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(136, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.13076923076923078, mode=row)
#             )
#             (18): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(816, 816, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=816, bias=False)
#                   (1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(816, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.13846153846153847, mode=row)
#             )
#             (19): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.14615384615384616, mode=row)
#             )
#             (20): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.15384615384615385, mode=row)
#             )
#             (21): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.16153846153846155, mode=row)
#             )
#             (22): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.16923076923076924, mode=row)
#             )
#             (23): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.17692307692307693, mode=row)
#             )
#             (24): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.18461538461538465, mode=row)
#             )
#             (25): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#                   (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.19230769230769232, mode=row)
#             )
#           )
#           (films): ModuleList(
#             (0): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=24, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=24, bias=True)
#             )
#             (1): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=24, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=24, bias=True)
#             )
#             (2): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=32, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=32, bias=True)
#             )
#             (3): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=32, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=32, bias=True)
#             )
#             (4): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=32, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=32, bias=True)
#             )
#             (5): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=48, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=48, bias=True)
#             )
#             (6): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=48, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=48, bias=True)
#             )
#             (7): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=48, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=48, bias=True)
#             )
#             (8): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (9): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (10): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (11): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (12): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (13): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (14): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (15): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (16): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (17): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (18): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (19): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (20): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (21): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (22): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (23): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (24): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=384, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=384, bias=True)
#             )
#             (25): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=384, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=384, bias=True)
#             )
#           )
#           (convNormAct1): Conv2dNormActivation(
#             (0): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#         )
#         (film_layer): FilmConditioning(
#           (_projection_add): Linear(in_features=512, out_features=1024, bias=True)
#           (_projection_mult): Linear(in_features=512, out_features=1024, bias=True)
#         )
#       )
#       (_token_learner): TokenLearnerModule(
#         (layerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (conv1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (gelu1): GELU(approximate='tanh')
#         (dropout1): Identity()
#         (conv2): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         (dropout2): Identity()
#       )
#     )
#     (1): RT1ImageTokenizer(
#       (_tokenizer): EfficientNetEncoder(
#         (conv1x1): Conv2d(1536, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (net): EfficientNet(
#           (convNormAct0): Conv2dNormActivation(
#             (0): Conv2d(3, 40, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (blocks): ModuleList(
#             (0): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#                   (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (2): Conv2dNormActivation(
#                   (0): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#             )
#             (1): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#                   (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (2): Conv2dNormActivation(
#                   (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.007692307692307693, mode=row)
#             )
#             (2): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#                   (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.015384615384615385, mode=row)
#             )
#             (3): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#                   (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.02307692307692308, mode=row)
#             )
#             (4): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
# ...
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.17692307692307693, mode=row)
#             )
#             (24): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(1392, 1392, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1392, bias=False)
#                   (1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.18461538461538465, mode=row)
#             )
#             (25): MBConvBlock(
#               (block): Sequential(
#                 (0): Conv2dNormActivation(
#                   (0): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (1): Conv2dNormActivation(
#                   (0): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2304, bias=False)
#                   (1): BatchNorm2d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): SiLU(inplace=True)
#                 )
#                 (2): SeModule(
#                   (avgpool): AdaptiveAvgPool2d(output_size=1)
#                   (fc1): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#                   (silu0): SiLU(inplace=True)
#                   (fc2): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#                   (act): Sigmoid()
#                 )
#                 (3): Conv2dNormActivation(
#                   (0): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                   (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#               )
#               (dropout): StochasticDepth(p=0.19230769230769232, mode=row)
#             )
#           )
#           (films): ModuleList(
#             (0): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=24, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=24, bias=True)
#             )
#             (1): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=24, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=24, bias=True)
#             )
#             (2): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=32, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=32, bias=True)
#             )
#             (3): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=32, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=32, bias=True)
#             )
#             (4): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=32, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=32, bias=True)
#             )
#             (5): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=48, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=48, bias=True)
#             )
#             (6): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=48, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=48, bias=True)
#             )
#             (7): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=48, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=48, bias=True)
#             )
#             (8): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (9): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (10): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (11): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (12): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=96, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=96, bias=True)
#             )
#             (13): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (14): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (15): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (16): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (17): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=136, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=136, bias=True)
#             )
#             (18): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (19): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (20): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (21): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (22): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (23): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=232, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=232, bias=True)
#             )
#             (24): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=384, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=384, bias=True)
#             )
#             (25): FilmConditioning(
#               (_projection_add): Linear(in_features=512, out_features=384, bias=True)
#               (_projection_mult): Linear(in_features=512, out_features=384, bias=True)
#             )
#           )
#           (convNormAct1): Conv2dNormActivation(
#             (0): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#         )
#         (film_layer): FilmConditioning(
#           (_projection_add): Linear(in_features=512, out_features=1024, bias=True)
#           (_projection_mult): Linear(in_features=512, out_features=1024, bias=True)
#         )
#       )
#       (_token_learner): TokenLearnerModule(
#         (layerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (conv1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (gelu1): GELU(approximate='tanh')
#         (dropout1): Identity()
#         (conv2): Conv2d(64, 8, kernel_size=(1, 1), stride=(1, 1))
#         (dropout2): Identity()
#       )
#     )
#   )
#   (language_embedding): Embedding(512, 512)
#   (_transformer): Transformer(
#     (_layers): ModuleList(
#       (0): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (1): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (2): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (3): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (4): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (5): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (6): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#       (7): _TransformerLayer(
#         (norm_1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): TF_MultiHeadAttention(
#           (q_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (k_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (v_linear): Linear(in_features=512, out_features=1024, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (out): Linear(in_features=1024, out_features=512, bias=True)
#         )
#         (ff): Linear(in_features=512, out_features=512, bias=True)
#         (norm_2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout_1): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (_token_emb): Linear(in_features=1024, out_features=512, bias=True)
#     (_position_emb): Embedding(256, 512)
#     (_output_tokens): Linear(in_features=512, out_features=256, bias=True)
#   )
#   (_loss_object): CrossEntropyLoss()
# )

# %%
# ls -lh pretrained_rt1.pth

# %%
# !file pretrained_rt1.pth
# Out:
# pretrained_rt1.pth: Zip archive data, at least v0.0 to extract, compression method=store

# %%
network.load_state_dict(checkpoint["model_state_dict"], strict=False)
# Out:
# _IncompatibleKeys(missing_keys=['language_embedding.weight'], unexpected_keys=[])

# %%
network.language_embedding = torch.nn.Embedding(
    num_embeddings=args["network_configs"]["vocab_size"],
    embedding_dim=args["network_configs"]["language_embedding_size"]
)

# %%
checkpoint = torch.load(args["resume_from_checkpoint"], map_location="cpu")
if "language_embedding.weight" not in checkpoint["model_state_dict"]:
    checkpoint["model_state_dict"]["language_embedding.weight"] = torch.empty(
        args["network_configs"]["vocab_size"],
        args["network_configs"]["language_embedding_size"]
    ).normal_(mean=0.0, std=0.01)  # Initialize randomly
    torch.save(checkpoint, args["resume_from_checkpoint"])

# %% [markdown]
# Load pretrained network parameters here by setting "resume" to True and giving path of saved network to args["resume_from_checkpoint"]

# %%
# Load model weights, optimizer, scheduler settings, resume from checkpoints if specified
args["resume_from_checkpoint"] = "pretrained_rt1.pth"
args["resume"] = True
if args["resume"]:
    checkpoint = torch.load(args["resume_from_checkpoint"], map_location="cpu")
    network.load_state_dict(checkpoint["model_state_dict"])
    print("loaded from: ", args["resume_from_checkpoint"])

total_params = sum(p.numel() for p in network.parameters() if p.requires_grad)
print("number of model params:", total_params)
total_size_bytes = total_params * 4
# Parameter is in torch.float32，Each parameter takes 4 bytes
total_size_mb = round(total_size_bytes / (1024 * 1024), 2)
print("model size: ", total_size_mb, " MB")
# Out:
# loaded from:  pretrained_rt1.pth
# number of model params: 54021184
# model size:  206.07  MB

# %% [markdown]
# Functions for sending all the tensor in dictionary to intended device, and retrieving the tensors at specific timestep of from a dictionary

# %%
def dict_to_device(dict_obj, device):
    """
    put all the values in the [dict_obj] to [device]
    """
    for k, v in dict_obj.items():
        assert isinstance(v, torch.Tensor)
        dict_obj[k] = v.to(device)
    return dict_obj


def retrieve_single_timestep(dict_obj, idx):
    """
    get all the values in the [dict_obj] at index [idx]
    v[:, idx], all the values in the dictionary at second dimension needs to be same
    """
    dict_obj_return = copy.deepcopy(dict_obj)
    for k, v in dict_obj.items():
        dict_obj_return[k] = v[:, idx]
    return dict_obj_return

# %% [markdown]
# Set training = True to start training, otherwise we can skip this block and using pretrained network to validate and visualize results

# %%
training = False
if training:
    optimizer = torch.optim.AdamW(network.parameters(), lr=args["lr"])
    train_dataloader = DataLoader(
        train_dataset,
        batch_size=args["batch_size"],
        num_workers=0,
        shuffle=True,
        drop_last=True,
    )
    for e in range(args["epochs"]):
        with tqdm(train_dataloader, dynamic_ncols=True, desc="train") as tqdmDataLoader:
            for _, (obs, action) in enumerate(tqdmDataLoader):
                optimizer.zero_grad()
                network.set_actions(dict_to_device(action, device))
                network_state = np_to_tensor(
                    batched_space_sampler(
                        network._state_space,
                        batch_size=args["batch_size"],
                    )
                )
                output_actions, network_state = network(
                    dict_to_device(obs, device),
                    dict_to_device(network_state, device),
                )

                loss = network.get_actor_loss().mean()

                loss.backward()
                optimizer.step()
                tqdmDataLoader.set_postfix(
                    ordered_dict={
                        "epoch": e,
                        "loss": loss.item(),
                        "gpu_memory_used": str(
                            round(torch.cuda.max_memory_allocated() / (1024**3), 2)
                        )
                        + " GB",
                        "lr": optimizer.state_dict()["param_groups"][0]["lr"],
                    }
                )

# %% [markdown]
# Set validating = False if you don't want to validate results, this function will output a set of images, each contains 8 subplots(corresponding to 8 action tokens output of model), each drawn with ground truth and output from model, on the title, the number marks the total loss value of this action.

# %%
validating = False
def visualize(all_gt, all_output):
    all_output = all_output[:, -1, :]
    all_gt = all_gt[:, -1, :]
    title = [
        "terminate_episode_l1_error: ",
        "cmd_pos_x_l1_error: ",
        "cmd_pos_y_l1_error: ",
        "cmd_pos_z_l1_error: ",
        "cmd_rot_x_l1_error: ",
        "cmd_rot_y_l1_error: ",
        "cmd_rot_z_l1_error: ",
        "cmd_gripper_l1_error: ",
    ]
    plt.figure(figsize=(22, 12))
    for i in range(8):
        c = utils.generate_random_color()
        plt.subplot(2, 4, i + 1)
        val_loss = F.l1_loss(
            torch.from_numpy(all_output[:, i]).float(),
            torch.from_numpy(all_gt[:, i]).float(),
        )
        plt.title(title[i] + str(val_loss.cpu().data.numpy()))
        plt.plot(all_gt[:, i], c=c, label="gt")
        plt.plot(all_output[:, i], c=c, linestyle="dashed", label="output")
        plt.xlabel("timesteps")
        plt.ylabel("action_tokens")
        plt.grid()
        plt.legend()
    plt.show()


val_dataloader = DataLoader(val_dataset, batch_size=1, shuffle=False, drop_last=False)
network.eval()
gt_one_episode = []
model_output_one_episode = []

if validating:
    for idx, (obs, action) in tqdm(
        enumerate(val_dataloader), desc="validation", total=len(val_dataset)
    ):
        # Initialize network state
        network_state = batched_space_sampler(network._state_space, batch_size=1)
        network_state = np_to_tensor(network_state)

        # Reset network state
        for k, v in network_state.items():
            network_state[k] = torch.zeros_like(v)

        action_predictions_logits = []
        output_actions = []

        for i_ts in range(args["time_sequence_length"]):
            ob = retrieve_single_timestep(obs, i_ts)
            output_action, network_state = network(
                dict_to_device(ob, device),
                dict_to_device(network_state, device),
            )
            output_actions.append(output_action)
            action_predictions_logits.append(
                network._aux_info["action_predictions_logits"]
            )

        # Get ground truth actions
        gt_actions = network._action_tokenizer.tokenize(action)
        action_predictions_logits = (
            torch.cat(action_predictions_logits, dim=0).unsqueeze(0).permute(0, 3, 1, 2)
        )
        gt_one_episode.append(gt_actions)
        model_output_one_episode.append(action_predictions_logits.argmax(1))

        # Handle end of episode scenario
        if gt_actions[0, -1, 0] == 2:
            # gt_actions[0, -1, 0] is the terminate signal for current episode, 2 indicates the end of episode
            # whtn terminate signal is triggered, we write this episode's test results into files
            gt_one_episode = torch.cat(gt_one_episode).cpu().data.numpy()
            model_output_one_episode = (
                torch.cat(model_output_one_episode).cpu().data.numpy()
            )

            # Visualize and store episode results

            visualize(gt_one_episode, model_output_one_episode)
            gt_one_episode = []
            model_output_one_episode = []

# %% [markdown]
# The following 3 blocks contains utilities for visualization on model results
#
# **[WIP] Not officially Released Version**

# %%
import threading

TASKS = {"touch": "TouchTaskEnv", "pick": "PickTaskEnv"}

CAM_INFO = {
    "front": [[0, 0, 0.7], 1.8, 180, -20, 0, 40],
    "fronttop": [[0, 0.5, 0.7], 1.5, 180, -60, 0, 35],
    "topdown": [[0, 0.35, 0], 2.0, 0, -90, 0, 45],
    "side": [[0, 0.35, 0.9], 1.5, 90, 0, 0, 40],
    "root": [[0, 0.6, 0.75], 1.3, -35, -5, 0, 40],
    "wrist": [],
}
cam_resolution = (1080, 864)


def get_cam_projection_matrix(cam_view):
    aspect = float(cam_resolution[0]) / cam_resolution[1]
    near_val = 0.1
    far_val = 100

    if cam_view == "wrist":
        fov = 100
        near_val = 0.018
    else:
        fov = CAM_INFO[cam_view][-1]
    cam_projection_matrix = p.computeProjectionMatrixFOV(
        fov=fov,
        aspect=aspect,
        nearVal=near_val,
        farVal=far_val,
    )
    return cam_projection_matrix


def get_view_matrix(cam_view, robot_id, ee_index):
    if cam_view == "wrist":
        eye_pos, eye_ori = p.getLinkState(
            robot_id,
            ee_index,
            computeForwardKinematics=True,
        )[0:2]
        eye_pos = list(eye_pos)
        eye_pos = p.multiplyTransforms(eye_pos, eye_ori, [0, 0, -0.05], [0, 0, 0, 1])[0]
        r_mat = p.getMatrixFromQuaternion(eye_ori)
        tx_vec = np.array([r_mat[0], r_mat[3], r_mat[6]])
        ty_vec = np.array([r_mat[1], r_mat[4], r_mat[7]])
        tz_vec = np.array([r_mat[2], r_mat[5], r_mat[8]])
        camera_position = np.array(eye_pos)
        target_position = eye_pos + 0.001 * tz_vec
        cam_view_matrix = p.computeViewMatrix(
            cameraEyePosition=camera_position,
            cameraTargetPosition=target_position,
            cameraUpVector=ty_vec,
        )
    else:
        cam_view_matrix = p.computeViewMatrixFromYawPitchRoll(
            CAM_INFO[cam_view][0],
            CAM_INFO[cam_view][1],
            CAM_INFO[cam_view][2],
            CAM_INFO[cam_view][3],
            CAM_INFO[cam_view][4],
            2,
        )
    return cam_view_matrix


def get_cam_view_img(cam_view, robot_id=None, ee_index=None):
    cam_view_matrix = get_view_matrix(cam_view, robot_id, ee_index)
    cam_projection_matrix = get_cam_projection_matrix(cam_view)
    (width, height, rgb_pixels, _, _) = p.getCameraImage(
        cam_resolution[0],
        cam_resolution[1],
        viewMatrix=cam_view_matrix,
        projectionMatrix=cam_projection_matrix,
    )
    rgb_array = np.array(rgb_pixels).reshape((height, width, 4)).astype(np.uint8)
    img = np.array(resize_and_crop(rgb_array[:, :, :3]))
    return img


def resize_and_crop(input_image, img_width=320, img_height=256):
    """Crop the image to 5:4 aspect ratio and resize it to 320x256 pixels."""
    input_image = Image.fromarray(input_image)
    width, height = input_image.size
    target_aspect = img_width / img_height
    current_aspect = width / height

    if current_aspect > target_aspect:
        # If the image is too wide, crop its width
        new_width = int(target_aspect * height)
        left_margin = (width - new_width) / 2
        input_image = input_image.crop((left_margin, 0, width - left_margin, height))
    elif current_aspect < target_aspect:
        # If the image is too tall, crop its height
        new_height = int(width / target_aspect)
        top_margin = (height - new_height) / 2
        input_image = input_image.crop((0, top_margin, width, height - top_margin))

    # Resize the image
    input_image = input_image.resize((img_width, img_height))
    return input_image


class Panda(object):
    def __init__(self):
        self.arm_dof = 7
        self.ee_index = 11
        self.finger_indice = [9, 10]
        self.home_j_pos = [1.22, -0.458, 0.31, -2.0, 0.20, 1.56, 2.32, 0.04, 0.04]

    def load(self):
        self.robot_id = p.loadURDF(
            "franka_panda/panda.urdf",
            [0, 0, 0.62],
            [0, 0, 0, 1],
            useFixedBase=True,
            flags=p.URDF_ENABLE_CACHED_GRAPHICS_SHAPES,
        )

        # create a constraint to keep the fingers centered, 9 and 10 for finger indices
        c = p.createConstraint(
            self.robot_id,
            self.finger_indice[0],
            self.robot_id,
            self.finger_indice[1],
            jointType=p.JOINT_GEAR,
            jointAxis=[1, 0, 0],
            parentFramePosition=[0, 0, 0],
            childFramePosition=[0, 0, 0],
        )
        p.changeConstraint(c, gearRatio=-1, erp=0.1, maxForce=50)

    def calc_ik(self, pose):
        return list(
            p.calculateInverseKinematics(
                self.robot_id,
                self.ee_index,
                pose[0],
                pose[1],
                [-7] * 7,
                [7] * 7,
                [7] * 7,
                self.home_j_pos,
                maxNumIterations=100,
                solver=p.IK_DLS,
            )
        )

    def reset_j_home(self, random_home=False):
        if random_home:
            for i in range(self.arm_dof):
                self.home_j_pos[i] += random.uniform(-np.pi / 10, np.pi / 10)
        self.reset_j_pos(self.home_j_pos)

    def reset_j_pos(self, j_pos):
        index = 0
        for j in range(p.getNumJoints(self.robot_id)):
            p.changeDynamics(self.robot_id, j, linearDamping=0, angularDamping=0)
            joint_type = p.getJointInfo(self.robot_id, j)[2]
            if joint_type in [
                p.JOINT_PRISMATIC,
                p.JOINT_REVOLUTE,
            ]:
                p.resetJointState(self.robot_id, j, j_pos[index])
                index = index + 1

    def move_j(self, j_pos):
        for i in range(self.arm_dof):
            max_vel = 1 if i == self.arm_dof - 1 else 0.5
            p.setJointMotorControl2(
                self.robot_id,
                i,
                p.POSITION_CONTROL,
                j_pos[i],
                maxVelocity=max_vel,
                force=5 * 240.0,
            )
        for i in self.finger_indice:
            p.setJointMotorControl2(
                self.robot_id,
                i,
                p.POSITION_CONTROL,
                j_pos[-1],
                maxVelocity=0.02,
                force=1000,
            )

    def is_j_arrived(self, j_pos, include_finger=True, threshold=1e-2):
        cur_joint_position = [
            s[0]
            for s in p.getJointStates(
                self.robot_id, list(range(self.arm_dof)) + self.finger_indice
            )
        ]
        diff_arm = np.abs(np.array(cur_joint_position) - np.array(j_pos))
        is_arrive = np.all(diff_arm[: self.arm_dof - 1] <= threshold)
        if include_finger:
            is_arrive = is_arrive and np.all(diff_arm[-2:] <= threshold)
        return is_arrive

    def is_ee_arrived(self, ee_pose, tar_obj_id=None, threshold=2 * 1e-2):
        panda_ee_pos = np.array(p.getLinkState(self.robot_id, self.ee_index)[0])
        diff_pos = np.abs(panda_ee_pos - ee_pose[0])
        is_arrive = np.all(diff_pos <= threshold)
        if tar_obj_id != None:
            is_arrive = is_arrive and p.getClosestPoints(
                self.robot_id, tar_obj_id, 1e-5
            )
        return is_arrive


class SimEnv(object):
    def __init__(self):
        p.setPhysicsEngineParameter(solverResidualThreshold=0)
        self.control_dt = 1.0 / 240.0
        self.reset_env_wait_time = 0.5
        self.robot = None
        self.tar_obj = None
        self.tar_obj_pose = None
        self.load_env()
        self.set_camera()
        self.reset_env()

    def load_env(self):
        raise NotImplementedError

    def reset_env(self):
        raise NotImplementedError

    def set_camera(self):
        # set camera configs
        # self.cam_resolution = (320, 256)
        self.cam_resolution = (1080, 864)
        self.cam_info = CAM_INFO
        self.cam_view_matrice = []
        for key, val in self.cam_info.items():
            if key == "wrist":
                self.cam_view_matrice.append([])
            else:
                self.cam_view_matrice.append(
                    p.computeViewMatrixFromYawPitchRoll(
                        val[0],
                        val[1],
                        val[2],
                        val[3],
                        val[4],
                        2,
                    )
                )

        self.cam_projection_matrix = p.computeProjectionMatrixFOV(
            fov=60,
            aspect=float(self.cam_resolution[0]) / self.cam_resolution[1],
            nearVal=0.1,
            farVal=100,
        )


class TouchTaskEnv(SimEnv):
    def __init__(self):
        super().__init__()

    def load_env(self):
        p.loadURDF("table/table.urdf", [0, 0.35, 0], [0, 0, 0, 1])
        self.tar_obj = p.loadURDF("/content/pytorch_rt1_with_trainer_and_tester/urdf/cube/cube.urdf", [0, 0, 0], globalScaling=0.04)
        p.changeVisualShape(self.tar_obj, -1, rgbaColor=[1, 0, 0, 1])
        self.robot = Panda()
        self.robot.load()

    def reset_tar_obj(self, tar_obj_range=None, tar_pos_rot=None, random_pos_rot=True):
        if random_pos_rot:
            x = random.uniform(tar_obj_range[0], tar_obj_range[1])
            y = random.uniform(tar_obj_range[2], tar_obj_range[3])
            r = random.uniform(tar_obj_range[4], tar_obj_range[5])
        else:
            x = tar_pos_rot[0]
            y = tar_pos_rot[1]
            r = tar_pos_rot[2]
        pos = [x, y, 0.645]
        rot = p.getQuaternionFromEuler([0, np.pi / 2, r])
        p.resetBasePositionAndOrientation(
            self.tar_obj,
            pos,
            rot,
        )
        self.tar_obj_pose = p.getBasePositionAndOrientation(self.tar_obj)

    def reset_env(self):
        self.robot.reset_j_home()
        time.sleep(1)


class PickTaskEnv(TouchTaskEnv):
    def __init__(self):
        super().__init__()

# %%
def inference(network, imgs):
    network_state = batched_space_sampler(network._state_space, batch_size=1)
    network_state = np_to_tensor(
        network_state
    )  # change np.ndarray type of sample values into tensor type
    for k, v in network_state.items():
        network_state[k] = torch.zeros_like(v).to(device)
    output_actions = []
    obs = dict()
    obs["image"] = torch.stack(imgs, dim=1).to(device)
    obs["natural_language_embedding"] = torch.ones(1, 6, 512).to(device)
    with torch.no_grad():
        for i_ts in range(6):
            ob = retrieve_single_timestep(obs, i_ts)
            output_action, network_state = network(ob, network_state)
            output_actions.append(output_action)
        action = output_actions[-1]
    action = dict_to_device(action, torch.device("cpu"))
    return [
        action["terminate_episode"].flatten().tolist(),
        action["world_vector"].flatten().tolist(),
        action["rotation_delta"].flatten().tolist(),
        action["gripper_closedness_action"].flatten().tolist(),
    ]

# %%
class SimTester:
    def __init__(self, task_name):
        p.connect(p.DIRECT)
        p.configureDebugVisualizer(p.COV_ENABLE_GUI, 0)
        p.setPhysicsEngineParameter(maxNumCmdPer1ms=1000)
        p.resetDebugVisualizerCamera(
            cameraDistance=1.5,
            cameraPitch=-20,
            cameraYaw=180,
            cameraTargetPosition=[0, 0, 0.6],
        )
        p.setAdditionalSearchPath(pdata.getDataPath())
        p.setGravity(0, 0, -9.8)
        self.task_env = globals()[TASKS[task_name]]()
        self.max_step = 100
        self.device = torch.device("cuda")

    def test_step(self, delta_ee_pos, delta_ee_rot, gripper_cmd, cam_view):
        try:
            # start = time.time()
            self.execute_action(delta_ee_pos, delta_ee_rot, gripper_cmd, cam_view)
            # print(time.time() - start)
        except func_timeout.exceptions.FunctionTimedOut:
            # print("time out for execute actions")
            pass
        self.update_imgs(cam_view)

    @func_set_timeout(0.2)
    def execute_action(
        self, delta_ee_pos, delta_ee_rot, gripper_cmd, cam_view, relative=True
    ):
        if relative:
            if self.last_ee_pose == None:
                last_ee_pose = p.getLinkState(
                    self.task_env.robot.robot_id, self.task_env.robot.ee_index
                )[0:2]
            else:
                last_ee_pose = self.last_ee_pose
            # delta_ee_pos = [0, 0, 0.05]
            cur_ee_pose = p.multiplyTransforms(
                last_ee_pose[0],
                last_ee_pose[1],
                delta_ee_pos,
                p.getQuaternionFromEuler(delta_ee_rot),
            )
        else:
            raise NotImplementedError
        tar_j_pos = self.task_env.robot.calc_ik([cur_ee_pose[0], cur_ee_pose[1]])
        if gripper_cmd[0] > 0 or self.gripper_triggered:
            tar_j_pos[-2:] = [0.01] * 2  # close gripper
            if not self.gripper_triggered:
                self.gripper_triggered = True
        else:
            tar_j_pos[-2:] = [0.04] * 2  # open gripper

        self.task_env.robot.move_j(tar_j_pos)
        while not (self.task_env.robot.is_j_arrived(tar_j_pos, threshold=1e-3)):
            p.stepSimulation()
            time.sleep(0.005)

    def reset_tester(self, cam_view):
        self.task_env.reset_env()
        self.reset_imgs(cam_view)
        self.last_ee_pose = None
        self.gripper_triggered = False
        self.episode_succ = [False, False]

    def reset_imgs(self, cam_view):
        self.imgs = [torch.zeros(1, 3, 256 * len(cam_view), 320)] * 6

    def update_imgs(self, cam_view):
        img = self.get_obs_img(cam_view)
        self.imgs.pop(0)
        self.imgs.append(torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0))

    def get_obs_img(self, cam_view):
        imgs = []
        for cview in cam_view:
            imgs.append(
                get_cam_view_img(
                    cview, self.task_env.robot.robot_id, self.task_env.robot.ee_index
                )
            )
        cur_img = np.concatenate(imgs, axis=0)
        return cur_img / 255.0

    def get_step_dist(self):
        c_point = p.getClosestPoints(
            self.task_env.robot.robot_id,
            self.task_env.tar_obj,
            distance=10,
            linkIndexA=10,
        )
        try:
            dist = min(np.array(c_point, dtype=object)[:, 8])
        except:
            return 0
        return dist

    def check_episode_succ(self):
        ee_z_pos = p.getLinkState(
            self.task_env.robot.robot_id, self.task_env.robot.ee_index
        )[0][2]
        tar_obj_z_pos = self.task_env.tar_obj_pose[0][2]
        contact_points = p.getContactPoints(
            self.task_env.robot.robot_id, self.task_env.tar_obj
        )
        if abs(ee_z_pos - tar_obj_z_pos) < 0.035 and len(contact_points) > 0:
            self.episode_succ[0] = True
        if ee_z_pos - tar_obj_z_pos > 0.1 and len(contact_points) > 0:
            self.episode_succ[1] = True
        return ee_z_pos - tar_obj_z_pos

def set_seed(seed = 3407):
    """
    set random seed to reproduce results
    """
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
set_seed()

# %% [markdown]
# Visualizing model results, Cube position can be assigned randomly or deterministically, now it is deterministically with random_pos_rot False and "sim_tester.task_env.reset_tar_obj(tar_pos_rot = tar_pos_rot, random_pos_rot = False)"
#
# You can set the cube's position randomly by setting the flag random_pos_rot True and give **tar_obj_range(not tar_pos_rot)** = [-0.3, 0.3, 0.4, 0.7, -np.pi / 2, np.pi / 2] where tar_pos_rot is a 3 element list contains [x, y, rotation]
# at the area with x(meter): [-0.3, 0.3], y(meter): [-0.3, 0.3] and rotation: [-np.pi / 2, np.pi / 2]

# %%
# network.eval()
# if p.isConnected():
#     p.disconnect()
# sim_tester = SimTester("pick")
# # sim_tester.reset_tester(args['cam_view'])
# tar_pos_rot = [0.2, 0.55, np.pi / 4]
# sim_tester.reset_tester(args["cam_view"])
# sim_tester.task_env.reset_tar_obj(tar_pos_rot=tar_pos_rot, random_pos_rot=False)
# sim_tester.update_imgs(args["cam_view"])
# vids = []
# for _ in trange(50):
#     imgs = sim_tester.imgs
#     start = time.time()
#     (
#         terminate_episode,
#         delta_ee_pos,
#         delta_ee_rot,
#         gripper_cmd,
#     ) = inference(network, imgs)
#     sim_tester.test_step(delta_ee_pos, delta_ee_rot, gripper_cmd, args["cam_view"])
#     vids.append(imgs[-1][0].permute(1, 2, 0).numpy() * 255)
# # visualize
# from IPython.display import Video

# vwrite("vis.mp4", vids)
# Video("vis.mp4", embed=True, width=320, height=512)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-474a0ccf092e> in <cell line: 11>()
#      17         delta_ee_rot,
#      18         gripper_cmd,
# ---> 19     ) = inference(network, imgs)
#      20     sim_tester.test_step(delta_ee_pos, delta_ee_rot, gripper_cmd, args["cam_view"])
#      21     vids.append(imgs[-1][0].permute(1, 2, 0).numpy() * 255)
#
# <ipython-input-24-5d30a3d9ef65> in inference(network, imgs)
#      13         for i_ts in range(6):
#      14             ob = retrieve_single_timestep(obs, i_ts)
# ---> 15             output_action, network_state = network(ob, network_state)
#      16             output_actions.append(output_action)
#      17         action = output_actions[-1]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /content/pytorch_rt1_with_trainer_and_tester/maruya24_rt1/transformer_network.py in forward(self, observations, network_state)
#     298         # context_image_tokens: (b, t, num_tokens, embedding_dim)
#     299         # action_tokens: (b, t, self._tokens_per_action)
# --> 300         context_image_tokens, action_tokens, attention_mask = self._get_tokens_and_mask(
#     301             observations, network_state
#     302         )
#
# /content/pytorch_rt1_with_trainer_and_tester/maruya24_rt1/transformer_network.py in _get_tokens_and_mask(self, observations, network_state)
#     531     ):
#     532         # tokenize all inputs
# --> 533         context_image_tokens, network_state = self._tokenize_images(
#     534             observations, network_state
#     535         )
#
# /content/pytorch_rt1_with_trainer_and_tester/maruya24_rt1/transformer_network.py in _tokenize_images(self, observations, network_state)
#     568
#     569         # return context from observation after check whether context is in observation.
# --> 570         context = self._extract_context_from_observation(
#     571             observations, input_t
#     572         )  # [b, t, emb-size] or None
#
# /content/pytorch_rt1_with_trainer_and_tester/maruya24_rt1/transformer_network.py in _extract_context_from_observation(self, observations, seq_len)
#     708             outer_rank = self._get_outer_rank(observations)
#     709
# --> 710             context = self.language_embedding(
#     711                 observations["natural_language_embedding"]
#     712             )  # [b, t, emb-size] or [b, emb-size]
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     158
#     159     def forward(self, input: Tensor) -> Tensor:
# --> 160         return F.embedding(
#     161             input, self.weight, self.padding_idx, self.max_norm,
#     162             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2208         # remove once script supports set_grad_enabled
#    2209         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2211
#    2212
#
# RuntimeError: Expected tensor for argument #1 'indices' to have one of the following scalar types: Long, Int; but got torch.cuda.FloatTensor instead (while checking arguments for embedding)

# %%
def inference(network, imgs):
    network_state = batched_space_sampler(network._state_space, batch_size=1)
    network_state = np_to_tensor(network_state)
    for k, v in network_state.items():
        network_state[k] = torch.zeros_like(v).to(device)
    output_actions = []
    obs = dict()
    obs["image"] = torch.stack(imgs, dim=1).to(device)
    # Ensure indices for embedding are integers
    obs["natural_language_embedding"] = torch.ones(1, 6, 512).to(device).long()
    with torch.no_grad():
        for i_ts in range(6):
            ob = retrieve_single_timestep(obs, i_ts)
            output_action, network_state = network(ob, network_state)
            output_actions.append(output_action)
        action = output_actions[-1]
    action = dict_to_device(action, torch.device("cpu"))
    return [
        action["terminate_episode"].flatten().tolist(),
        action["world_vector"].flatten().tolist(),
        action["rotation_delta"].flatten().tolist(),
        action["gripper_closedness_action"].flatten().tolist(),
    ]
